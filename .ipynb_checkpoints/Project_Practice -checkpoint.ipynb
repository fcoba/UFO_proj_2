# %%
import sqlite3 
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('master.csv')
# df.head()

# %%
conn = sqlite3.connect('/Users/filis/flatiron2019/suicides.db')

# %%
c = conn.cursor()

# %%
c.execute('''select * from suicides''')

# %%
suicides_df = pd.DataFrame(c.fetchall())

# %%
suicides_df.columns = [i[0] for i in c.description]

# %%
suicides_df
# Out:
#           country  year     sex          age suicides_no population  \
# 0         Albania  1987    male  15-24 years          21     312900
# 1         Albania  1987    male  35-54 years          16     308000
# 2         Albania  1987  female  15-24 years          14     289700
# 3         Albania  1987    male    75+ years           1      21800
# 4         Albania  1987    male  25-34 years           9     274300
# 5         Albania  1987  female    75+ years           1      35600
# 6         Albania  1987  female  35-54 years           6     278800
# 7         Albania  1987  female  25-34 years           4     257200
# 8         Albania  1987    male  55-74 years           1     137500
# 9         Albania  1987  female   5-14 years           0     311000
# 10        Albania  1987  female  55-74 years           0     144600
# 11        Albania  1987    male   5-14 years           0     338200
# 12        Albania  1988  female    75+ years           2      36400
# ...

# %%
c.execute('''select * from suicides where country= 'Albania' ''')
suicides_df_alb = pd.DataFrame(c.fetchall())
suicides_df_alb.columns = [i[0] for i in c.description]

# %%
c.execute('''select * from suicides where country= 'United States' ''')
suicides_df_usa = pd.DataFrame(c.fetchall())
suicides_df_usa.columns = [i[0] for i in c.description]

# %%
c.execute('''select * from suicides where country= 'Albania' and age='75+ years' ''')
suicides_df_alb = pd.DataFrame(c.fetchall())
suicides_df_alb.columns = [i[0] for i in c.description]

# %%
c.execute('''select * from suicides where country= 'United States' and age='75+ years' ''')
suicides_df_usa = pd.DataFrame(c.fetchall())
suicides_df_usa.columns = [i[0] for i in c.description]

# %%
# suicides_df_usa

# %%
c.execute('''select year, sum(suicides_no) as num_suicides, 
sum(population) as total_pop
,((sum(suicides_no)*100000.0) / (sum(population))) as suicide_rate 
        from suicides 
        where country= 'United States' and age='75+ years' 
        group by year ''')

# %%
# c.fetchall()

# %%
suicides_df_usa = pd.DataFrame(c.fetchall())
suicides_df_usa.columns = [i[0] for i in c.description]

# %%
suicides_df_alb
# Out:
#     country  year     sex        age suicides_no population suicides/100k pop  \
# 0   Albania  1987    male  75+ years           1      21800              4.59
# 1   Albania  1987  female  75+ years           1      35600              2.81
# 2   Albania  1988  female  75+ years           2      36400              5.49
# 3   Albania  1988    male  75+ years           1      22300              4.48
# 4   Albania  1989    male  75+ years           2      22500              8.89
# 5   Albania  1989  female  75+ years           0      37000                 0
# 6   Albania  1992  female  75+ years           0      38700                 0
# 7   Albania  1992    male  75+ years           0      23900                 0
# 8   Albania  1993    male  75+ years           1      24200              4.13
# 9   Albania  1993  female  75+ years           0      39300                 0
# 10  Albania  1994    male  75+ years           2      24600              8.13
# ...

# %%
# suicides_df_usa

# %%
c.execute('''select SQL from SQLITE_Master''')

# %%
c.execute('''select year, sum(suicides_no) as num_suicides, 
sum(population) as total_pop
,((sum(suicides_no)*100000.0) / (sum(population))) as suicide_rate 
        from suicides 
        where country= 'Albania' and age='75+ years' 
        group by year ''')

suicides_df_alb = pd.DataFrame(c.fetchall())
suicides_df_alb.columns = [i[0] for i in c.description]

# %%
from scipy.stats import ttest_ind

# %%
ttest_ind(suicides_df_alb['suicide_rate'], suicides_df_usa['suicide_rate'], equal_var=False)
# Out:
# Ttest_indResult(statistic=-16.81652385166555, pvalue=1.1420531581905018e-20)

# %%
# if p is very small less than 0.05 then you reject null, meaning that the two things you are compaing are very different. 
# Albania has much lower suicide rate than USA.

# %%
suicides_df_alb['suicide_rate']
# Out:
# 0      3.484321
# 1      5.110733
# 2      3.361345
# 3      0.000000
# 4      1.574803
# 5      6.201550
# 6      4.552352
# 7      6.006006
# 8      7.407407
# 9      4.405286
# 10    10.248902
# 11     4.784689
# 12     3.831515
# 13     6.376412
# 14     8.562167
# 15     8.092860
# 16     0.000000
# 17     0.000000
# 18    11.025358
# 19     6.734460
# 20     0.000000
# 21     3.472765
# Name: suicide_rate, dtype: float64
